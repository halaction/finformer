# %% [markdown]
# # Finformer - Model

# %%
import os
import requests
from dotenv import load_dotenv
import json
import pandas as pd

from tqdm import tqdm, trange

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
load_dotenv()

DATA_PATH = './data'
os.makedirs(DATA_PATH, exist_ok=True)

news_path = os.path.join(DATA_PATH, 'data-news-intersection.csv')
prices_path = os.path.join(DATA_PATH, 'data-prices-intersection.csv')

# %%
# !pwd
# Out:
# /Users/ruastg1/Documents/study/sentiment/finformer

# %%
from finformer.data.fmp import load_data, collect_data

# %%
load_data()
# Out:
# 537 ['WLTW', 'EG', 'VLTO', 'PM', 'ETSY', 'NCLH', 'AKAM', 'COST', 'ERI', 'ENPH', 'BRO', 'APD', 'PTC', 'EMR', 'KEY', 'SBUX', 'TGT', 'KHC', 'ALB', 'ADI', 'VRTX', 'EMN', 'EIX', 'ZTS', 'GE', 'FTV', 'EW', 'KMB', 'NWS', 'BKNG', 'BWA', 'FITB', 'FSLR', 'UDR', 'VRSK', 'LOW', 'FOXA', 'GOOG', 'HII', 'APA', 'ES', 'LRCX', 'STE', 'HSIC', 'DXCM', 'CCEP', 'ON', 'PHM', 'OXY', 'ATO', 'BLDR', 'MPC', 'CSX', 'SWKS', 'PNR', 'FICO', 'KEYS', 'MO', 'AMD', 'HRL', 'NWSA', 'VLO', 'BSX', 'EQIX', 'HSY', 'PG', 'ESS', 'ORCL', 'ULTA', 'OKE', 'MRO', 'NVDA', 'ALLE', 'TRMB', 'DAL', 'ADP', 'PKG', 'DE', 'O', 'DUK', 'VIAC', 'FI', 'TSN', 'MS', 'GEHC', 'CAH', 'DIS', 'KIM', 'DVN', 'VTRS', 'ILMN', 'LVS', 'HUM', 'PEP', 'OMC', 'ECL', 'NTRS', 'NLOK', 'CI', 'SLB', 'SPGI', 'VICI', 'SCHW', 'HIG', 'NRG', 'TT', 'IEX', 'CINF', 'LYV', 'CMS', 'PEG', 'MSFT', 'TRGP', 'VRSN', 'EQT', 'LLY', 'ICE', 'NTAP', 'ABT', 'MMM', 'AME', 'CFG', 'CHD', 'LNT', 'XEL', 'REG', 'GPN', 'WMT', 'HPQ', 'AMT', 'JNJ', 'IQV', 'RL', 'AVB', 'FANG', 'JKHY', 'C', 'LHX',
# ...

# %%
collect_data()
# Out:
# 537 ['WLTW', 'EG', 'VLTO', 'PM', 'ETSY', 'NCLH', 'AKAM', 'COST', 'ERI', 'ENPH', 'BRO', 'APD', 'PTC', 'EMR', 'KEY', 'SBUX', 'TGT', 'KHC', 'ALB', 'ADI', 'VRTX', 'EMN', 'EIX', 'ZTS', 'GE', 'FTV', 'EW', 'KMB', 'NWS', 'BKNG', 'BWA', 'FITB', 'FSLR', 'UDR', 'VRSK', 'LOW', 'FOXA', 'GOOG', 'HII', 'APA', 'ES', 'LRCX', 'STE', 'HSIC', 'DXCM', 'CCEP', 'ON', 'PHM', 'OXY', 'ATO', 'BLDR', 'MPC', 'CSX', 'SWKS', 'PNR', 'FICO', 'KEYS', 'MO', 'AMD', 'HRL', 'NWSA', 'VLO', 'BSX', 'EQIX', 'HSY', 'PG', 'ESS', 'ORCL', 'ULTA', 'OKE', 'MRO', 'NVDA', 'ALLE', 'TRMB', 'DAL', 'ADP', 'PKG', 'DE', 'O', 'DUK', 'VIAC', 'FI', 'TSN', 'MS', 'GEHC', 'CAH', 'DIS', 'KIM', 'DVN', 'VTRS', 'ILMN', 'LVS', 'HUM', 'PEP', 'OMC', 'ECL', 'NTRS', 'NLOK', 'CI', 'SLB', 'SPGI', 'VICI', 'SCHW', 'HIG', 'NRG', 'TT', 'IEX', 'CINF', 'LYV', 'CMS', 'PEG', 'MSFT', 'TRGP', 'VRSN', 'EQT', 'LLY', 'ICE', 'NTAP', 'ABT', 'MMM', 'AME', 'CFG', 'CHD', 'LNT', 'XEL', 'REG', 'GPN', 'WMT', 'HPQ', 'AMT', 'JNJ', 'IQV', 'RL', 'AVB', 'FANG', 'JKHY', 'C', 'LHX',
# ...

# %%
df = pd.read_csv('./data/raw-dataset/tickers.csv')

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df = pd.read_csv('./data/raw-dataset/tickers.csv')
#       3 df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv('./data/raw-dataset/metrics.csv')

len(df['symbol'].unique())
df.groupby(by='symbol').count().sort_values(by='date')
# Out:
#         date  calendarYear  period  revenuePerShare  netIncomePerShare  \
# symbol
# KVUE       9             9       9                9                  9
# GEHC       9             9       9                9                  9
# VLTO       9             9       9                9                  9
# GFS       14            14      14               14                 14
# DASH      17            17      17               17                 17
# ...      ...           ...     ...              ...                ...
# MTCH     236           236     236              236                236
# CTRA     267           267     267              267                267
# RTX      277           277     277              277                277
# GEN      286           286     286              286                286
# RVTY     300           300     300              300                300
#
#         operatingCashFlowPerShare  freeCashFlowPerShare  cashPerShare  \
# symbol
# ...

# %%
df = pd.read_csv('./data/raw-dataset/prices.csv')

len(df['symbol'].unique())
df.groupby(by='symbol').count().sort_values(by='date')
# Out:
#         date  open  high   low  close  adjClose  volume  unadjustedVolume  \
# symbol
# VLTO     147   147   147   147    147       147     147               147
# KVUE     247   247   247   247    247       247     247               247
# GEHC     342   342   342   342    342       342     342               342
# CEG      571   571   571   571    571       571     571               571
# GFS      627   627   627   627    627       627     627               627
# ...      ...   ...   ...   ...    ...       ...     ...               ...
# RVTY    6973  6973  6973  6973   6973      6973    6973              6973
# EG      7003  7003  7003  7003   7003      7003    7003              7003
# COR     7058  7058  7058  7058   7058      7058    7058              7058
# DOC     7143  7143  7143  7143   7143      7143    7143              7143
# MTCH    7206  7206  7206  7206   7206      7206    7206              7206
#
#         change  changePercent  vwap  label  changeOverTime
# symbol
# ...

# %%
df = pd.read_csv('./data/raw-dataset/news.csv')

df.groupby(by='symbol').count().sort_values(by='publishedDate')
# Out:
#         publishedDate  title  image   site   text    url
# symbol
# VLTO               13     13     13     13     13     13
# BF-B              129    129    129    129    129    129
# TECH              136    136    136    136    136    136
# STE               138    138    138    138    138    138
# WAT               145    145    145    145    145    145
# ...               ...    ...    ...    ...    ...    ...
# MSFT            13824  13824  13822  13824  13804  13824
# GOOG            15578  15578  15493  15578  15571  15578
# META            17721  17721  17720  17721  17703  17721
# TSLA            20000  20000  20000  20000  19991  20000
# AAPL            22500  22500  22498  22500  22466  22500
#
# [319 rows x 6 columns]

# %%
df[df['symbol'] == 'CPAY']
# Out:
#        symbol        publishedDate  \
# 136603   CPAY  2024-03-25 10:46:23
# 136604   CPAY  2024-03-04 10:51:07
# 136605   CPAY  2024-02-18 23:51:12
# 136606   CPAY  2024-02-16 08:59:00
# 136607   CPAY  2024-02-15 10:46:08
# ...       ...                  ...
# 136934   CPAY  2020-04-03 08:28:51
# 136935   CPAY  2020-04-03 07:44:50
# 136936   CPAY  2020-04-01 19:56:05
# 136937   CPAY  2020-04-01 15:31:00
# 136938   CPAY  2020-04-01 00:00:00
#
#                                                     title  \
# 136603  Why FleetCor Technologies (FLT) is a Top Value...
# 136604  Here's Why FleetCor Technologies (FLT) is a St...
# 136605  Fleetcor: A High-Quality Company Undervalued O...
# 136606  FLEETCOR to Participate in Upcoming Investor C...
# 136607  Why FleetCor Technologies (FLT) is a Top Growt...
# ...                                                   ...
# 136934  Advisors Asset Management Inc. Trims Holdings ...
# 136935  FleetCor Technologies, Inc. (NYSE:FLT) Short I...
# ...

# %%
df.groupby(by='symbol').count().sort_values(by='publishedDate')
# Out:
#         publishedDate  title  image   site   text    url
# symbol
# VLTO               13     13     13     13     13     13
# BF-B              129    129    129    129    129    129
# TECH              136    136    136    136    136    136
# STE               138    138    138    138    138    138
# WAT               145    145    145    145    145    145
# ...               ...    ...    ...    ...    ...    ...
# MSFT            13824  13824  13822  13824  13804  13824
# GOOG            15578  15578  15493  15578  15571  15578
# META            17721  17721  17720  17721  17703  17721
# TSLA            20000  20000  20000  20000  19991  20000
# AAPL            22500  22500  22498  22500  22466  22500
#
# [319 rows x 6 columns]

# %%
df = pd.read_csv('./data/raw-dataset/news.csv')

len(df['symbol'].unique())
# Out:
# 319

# %%
df = pd.read_csv('./data/raw-dataset/profile.csv')

len(df['symbol'].unique())
# Out:
# 17

# %%
df = pd.read_csv('./data/fmp/profile/profile.csv')

# %%
df['symbol'].unique().shape
# Out:
# (515,)

# %%
df_tickers = pd.read_csv('./data/fmp/tickers.csv')

df_tickers
# Out:
#     symbol                      name                  sector  \
# 0      GEV                GE Vernova             Industrials
# 1     SOLV                 Solventum             Health Care
# 2     DECK            Deckers Brands  Consumer Discretionary
# 3     SMCI                Supermicro  Information Technology
# 4     BLDR      Builders FirstSource             Industrials
# ..     ...                       ...                     ...
# 599    WBA  Walgreens Boots Alliance              Healthcare
# 600    WBD    Warner Bros. Discovery  Communication Services
# 601   WDAY             Workday, Inc.              Technology
# 602    XEL               Xcel Energy               Utilities
# 603     ZS                   Zscaler              Technology
#
#                                       subSector               headQuarter  \
# 0                    Heavy Electrical Equipment  Cambridge, Massachusetts
# 1                        Health Care Technology     Saint Paul, Minnesota
# ...

# %%
df_changes = pd.read_csv('./data/fmp/changes.csv')

df_changes
# Out:
#             date                                               name oldSymbol  \
# 0     2024-04-19  Xylo Technologies Ltd. American Depositary Shares      MDGS
# 1     2024-04-19  Xylo Technologies Ltd. American Depositary Shares      XLYO
# 2     2024-04-18  Xylo Technologies Ltd. American Depositary Shares      MDGS
# 3     2024-04-17                iLearningEngines, Inc. Common Stock      ARRW
# 4     2024-04-17                     iLearningEngines, Inc. Warrant     ARRWW
# ...          ...                                                ...       ...
# 4584  1998-02-13                                          Infogroup     ABIIB
# 4585  1998-02-10                                             Ventas        VC
# 4586  1998-02-03                            Morton Industrial Group      MLXR
# 4587  1998-01-20                         Grand Central Silver Mines      CTMC
# 4588  1998-01-02                           Questcor Pharmaceuticals      CYPR
#
#      newSymbol symbol
# ...

# %%
df = pd.read_csv('data/fmp/news/AAPL.csv')

# %%
start_date = pd.to_datetime('2020-01-01', format='%Y-%m-%d').date()
end_date = pd.to_datetime('2024-04-15', format='%Y-%m-%d').date()

df_tickers.drop_duplicates(inplace=True)

columns = df_tickers.columns

df_tickers['_date_first_added'] = pd.to_datetime(df_tickers['dateFirstAdded'].str.strip().combine_first(df_tickers['founded']), format='%Y-%m-%d').dt.date
df_tickers['_delta_first_added'] = end_date - df_tickers['_date_first_added']

print(df_tickers['symbol'].unique().shape)
# Out:
# (520,)

# %%
df_tickers
# Out:
#     symbol                      name                  sector  \
# 0      GEV                GE Vernova             Industrials
# 1     SOLV                 Solventum             Health Care
# 2     DECK            Deckers Brands  Consumer Discretionary
# 3     SMCI                Supermicro  Information Technology
# 4     BLDR      Builders FirstSource             Industrials
# ..     ...                       ...                     ...
# 599    WBA  Walgreens Boots Alliance              Healthcare
# 600    WBD    Warner Bros. Discovery  Communication Services
# 601   WDAY             Workday, Inc.              Technology
# 602    XEL               Xcel Energy               Utilities
# 603     ZS                   Zscaler              Technology
#
#                                       subSector               headQuarter  \
# 0                    Heavy Electrical Equipment  Cambridge, Massachusetts
# 1                        Health Care Technology     Saint Paul, Minnesota
# ...

# %%
sp500 = set(df_tickers[df_tickers['index_name'] == 'sp500']['symbol'].unique())
nasdaq = set(df_tickers[df_tickers['index_name'] == 'nasdaq']['symbol'].unique())

# %%
df_tickers['symbol'].value_counts()[df_tickers['symbol'].value_counts() > 1]
# Out:
# MAR     2
# MDLZ    2
# IDXX    2
# PAYX    2
# CDW     2
#        ..
# GILD    2
# VRTX    2
# CEG     2
# CTSH    2
# KHC     2
# Name: symbol, Length: 84, dtype: int64

# %%
nasdaq - sp500
# Out:
# {'ASML',
#  'AZN',
#  'CCEP',
#  'CRWD',
#  'DASH',
#  'DDOG',
#  'GFS',
#  'MDB',
#  'MELI',
#  'MRVL',
#  'PDD',
#  'SIRI',
#  'SPLK',
#  'TEAM',
#  'TTD',
#  'WDAY',
#  'ZS'}

# %%
df_tickers['_date'] = df_tickers['dateFirstAdded'].combine_first(df_tickers['founded'])

df_tickers
# Out:
#     symbol                      name                  sector  \
# 0      GEV                GE Vernova             Industrials
# 1     SOLV                 Solventum             Health Care
# 2     DECK            Deckers Brands  Consumer Discretionary
# 3     SMCI                Supermicro  Information Technology
# 4     BLDR      Builders FirstSource             Industrials
# ..     ...                       ...                     ...
# 599    WBA  Walgreens Boots Alliance              Healthcare
# 600    WBD    Warner Bros. Discovery  Communication Services
# 601   WDAY             Workday, Inc.              Technology
# 602    XEL               Xcel Energy               Utilities
# 603     ZS                   Zscaler              Technology
#
#                                       subSector               headQuarter  \
# 0                    Heavy Electrical Equipment  Cambridge, Massachusetts
# 1                        Health Care Technology     Saint Paul, Minnesota
# ...

# %%
condition = (
    (df_tickers['_date_first_added'] <= end_date) 
    & (df_tickers['_delta_first_added'].dt.days > 30)
)

df_tickers = df_tickers.loc[condition, columns]

print(df_tickers['symbol'].unique().shape)
# Out:
# (516,)

# %%
df_tickers
# Out:
#     symbol                      name                  sector  \
# 4     BLDR      Builders FirstSource             Industrials
# 5      JBL                     Jabil  Information Technology
# 6     UBER                      Uber             Industrials
# 7     HUBB      Hubbell Incorporated             Industrials
# 8     LULU       Lululemon Athletica  Consumer Discretionary
# ..     ...                       ...                     ...
# 599    WBA  Walgreens Boots Alliance              Healthcare
# 600    WBD    Warner Bros. Discovery  Communication Services
# 601   WDAY             Workday, Inc.              Technology
# 602    XEL               Xcel Energy               Utilities
# 603     ZS                   Zscaler              Technology
#
#                                         subSector                headQuarter  \
# 4                               Building Products              Irving, Texas
# ...

# %%
def rename_indicator(row: pd.Series):

    classes = (' A', ' B')
    class_change = row['oldSymbol'].endswith(classes)
    identifier_change = row['oldSymbol'].startswith(row['newSymbol'])

    condition = not (class_change or identifier_change)
    
    return condition


tickers = df_tickers['symbol'].unique().tolist()

columns = df_changes.columns

df_changes['_rename_indicator'] = df_changes.apply(rename_indicator, axis=1)
df_changes['_date'] = pd.to_datetime(df_changes['date'], format='%Y-%m-%d').dt.date

condition = (
    (df_changes['_date'] >= start_date)  
    & df_changes['newSymbol'].isin(tickers) 
    & (~ df_changes['oldSymbol'].isin(tickers))
    & df_changes['_rename_indicator']
)

df_changes = df_changes.loc[condition, columns]

tickers.extend(df_changes['oldSymbol'].unique().tolist())
tickers = list(set(tickers))

print(df_tickers['symbol'].unique().shape)
# Out:
# (516,)

# %%
df_changes
# Out:
#             date                                               name oldSymbol  \
# 24    2024-03-25                          Corpay, Inc. Common Stock       FLT
# 41    2024-03-04           Healthpeak Properties, Inc. Common Stock      PEAK
# 69    2024-02-01                        Dayforce, Inc. Common Stock      CDAY
# 191   2023-08-30                         Cencora, Inc. Common Stock       ABC
# 234   2023-07-10                   Everest Group, Ltd. Common Stock        RE
# 277   2023-05-16                         Revvity, Inc. Common Stock       PKI
# 419   2022-11-08                      Gen Digital Inc. Common Stock      NLOK
# 542   2022-06-28                 Elevance Health, Inc. Common Stock      ANTM
# 547   2022-06-09                               Meta Platforms, Inc.        FB
# 565   2022-05-10                      Ball Corporation Common Stock       BLL
# 613   2022-02-17  Paramount Global 5.75% Series A Mandatory Conv...      VIAC
# ...

# %%
changes = dict(zip(df_changes['oldSymbol'], df_changes['newSymbol']))

print(len(tickers), tickers)
print(len(changes), changes)
# Out:
# 537 ['WLTW', 'EG', 'VLTO', 'PM', 'ETSY', 'NCLH', 'AKAM', 'COST', 'ERI', 'ENPH', 'BRO', 'APD', 'PTC', 'EMR', 'KEY', 'SBUX', 'TGT', 'KHC', 'ALB', 'ADI', 'VRTX', 'EMN', 'EIX', 'ZTS', 'GE', 'FTV', 'EW', 'KMB', 'NWS', 'BKNG', 'BWA', 'FITB', 'FSLR', 'UDR', 'VRSK', 'LOW', 'FOXA', 'GOOG', 'HII', 'APA', 'ES', 'LRCX', 'STE', 'HSIC', 'DXCM', 'CCEP', 'ON', 'PHM', 'OXY', 'ATO', 'BLDR', 'MPC', 'CSX', 'SWKS', 'PNR', 'FICO', 'KEYS', 'MO', 'AMD', 'HRL', 'NWSA', 'VLO', 'BSX', 'EQIX', 'HSY', 'PG', 'ESS', 'ORCL', 'ULTA', 'OKE', 'MRO', 'NVDA', 'ALLE', 'TRMB', 'DAL', 'ADP', 'PKG', 'DE', 'O', 'DUK', 'VIAC', 'FI', 'TSN', 'MS', 'GEHC', 'CAH', 'DIS', 'KIM', 'DVN', 'VTRS', 'ILMN', 'LVS', 'HUM', 'PEP', 'OMC', 'ECL', 'NTRS', 'NLOK', 'CI', 'SLB', 'SPGI', 'VICI', 'SCHW', 'HIG', 'NRG', 'TT', 'IEX', 'CINF', 'LYV', 'CMS', 'PEG', 'MSFT', 'TRGP', 'VRSN', 'EQT', 'LLY', 'ICE', 'NTAP', 'ABT', 'MMM', 'AME', 'CFG', 'CHD', 'LNT', 'XEL', 'REG', 'GPN', 'WMT', 'HPQ', 'AMT', 'JNJ', 'IQV', 'RL', 'AVB', 'FANG', 'JKHY', 'C', 'LHX',
# ...

# %%
len(set(tickers) - set(changes.keys()))
# Out:
# 516

# %% [markdown]
# ## Data

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from finformer.data.dataset import get_dataset

# %%
dataset = get_dataset(force=False)
# Out:
# Dataset profile exists!
# Dataset news exists!
# Dataset prices exists!
# Dataset metrics exists!

# %%
dataset.prices
# Out:
#                date    open    high     low   close  adjClose    volume  \
# 0        2024-04-15  142.31  143.25  140.26  140.34    140.34    433934
# 1        2024-04-12  143.59  144.66  140.26  140.73    140.73   1124506
# 2        2024-04-11  145.65  145.86  143.67  145.00    145.00    720175
# 3        2024-04-10  144.42  145.06  143.55  144.16    144.16   1051822
# 4        2024-04-09  146.00  147.43  145.50  147.40    147.40    873691
# ...             ...     ...     ...     ...     ...       ...       ...
# 1763915  2013-02-07   31.00   32.73   31.00   32.00     29.54   3800800
# 1763916  2013-02-06   30.98   31.43   30.75   31.03     28.64   2126100
# 1763917  2013-02-05   31.25   31.98   30.85   31.04     28.65   5013200
# 1763918  2013-02-04   31.09   31.99   30.76   31.02     28.64   7695400
# 1763919  2013-02-01   31.50   31.74   30.47   31.01     28.63  66789100
#
#          unadjustedVolume  change  changePercent      vwap            label  \
# ...

# %%
df_news = pd.read_csv(news_path)
df_prices = pd.read_csv(prices_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_news = pd.read_csv(news_path)
#       2 df_prices = pd.read_csv(prices_path)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ## Sentiment Analysis Model

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 3
#       1 from transformers import AutoTokenizer, AutoModelForSequenceClassification
# ----> 3 tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
#       4 model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/tokenization_auto.py:109, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     107     return RobertaTokenizer.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     108 elif 'bert' in pretrained_model_name_or_path:
# --> 109     return BertTokenizer.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     110 elif 'openai-gpt' in pretrained_model_name_or_path:
# ...

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Time Series Forecasting Model
